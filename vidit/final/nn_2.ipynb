# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("7.csv")

# %%
data["col0_encoded"] = data.iloc[:, 0].astype("category").cat.codes + 1

# %%
X = data.iloc[:, 1:]
y = data.iloc[:, 0]

train_data, temp_data = train_test_split(data, test_size=0.4, stratify=data.iloc[:, -1], random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, stratify=temp_data.iloc[:, -1], random_state=42)

# %%
train_data.reset_index(drop=True, inplace=True)
test_data.reset_index(drop=True, inplace=True)
val_data.reset_index(drop=True, inplace=True)

# %%
# Define features (last 3 columns excluding the target)
X_train = train_data.iloc[:, -4:-1]
X_val = val_data.iloc[:, -4:-1]
X_test = test_data.iloc[:, -4:-1]

# Define target (last column)
y_train = train_data.iloc[:, -1]
y_val = val_data.iloc[:, -1]
y_test = test_data.iloc[:, -1]

# %%
# ✅ Standardize the Data
scaler = StandardScaler()
X_train_scaled = torch.tensor(scaler.fit_transform(X_train), dtype=torch.float32)
X_val_scaled = torch.tensor(scaler.transform(X_val), dtype=torch.float32)

# ✅ Convert Labels (zero-indexed for PyTorch)
y_train_tensor = torch.tensor(y_train.values - 1, dtype=torch.long)
y_val_tensor = torch.tensor(y_val.values - 1, dtype=torch.long)

# ✅ Create DataLoaders
train_dataset = TensorDataset(X_train_scaled, y_train_tensor)
val_dataset = TensorDataset(X_val_scaled, y_val_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# ✅ Define the Neural Network
class FishClassifier(nn.Module):
    def __init__(self, input_size, hidden_size=256, num_classes=9):
        super(FishClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size // 2)
        self.fc4 = nn.Linear(hidden_size // 2, num_classes)
        self.dropout = nn.Dropout(p=0.4)

    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# ✅ Initialize Model, Loss, Optimizer
input_dim = X_train.shape[1]
model = FishClassifier(input_size=input_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.005)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)

# ✅ Training Loop
num_epochs = 200
train_loss_list = []
val_acc_list = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    scheduler.step()
    avg_loss = total_loss / len(train_loader)
    train_loss_list.append(avg_loss)

    # ✅ Validation
    model.eval()
    correct, total = 0, 0
    all_preds = []
    all_targets = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_targets.extend(y_batch.cpu().numpy())
    
    acc = correct / total
    val_acc_list.append(acc)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Validation Accuracy: {acc:.4f}")

# ✅ Save Model
torch.save(model.state_dict(), "fish_classifier.pth")

# ✅ Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_preds, digits=4))

# ✅ Confusion Matrix
cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig('nn_confusion_matrix.png', dpi=300)
plt.close()
print("Confusion matrix saved as nn_confusion_matrix.png")

# ✅ Metrics
acc_score = accuracy_score(all_targets, all_preds)
precision = precision_score(all_targets, all_preds, average='weighted')
recall = recall_score(all_targets, all_preds, average='weighted')
f1 = f1_score(all_targets, all_preds, average='weighted')
print(f"\nFinal Metrics:")
print(f"✅ Accuracy:  {acc_score:.4f}")
print(f"✅ Precision: {precision:.4f}")
print(f"✅ Recall:    {recall:.4f}")
print(f"✅ F1 Score:  {f1:.4f}")

# ✅ Plot Accuracy & Loss Over Epochs
plt.figure(figsize=(10, 6))
plt.plot(val_acc_list, label="Validation Accuracy", color='blue')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy Over Epochs")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("nn_val_accuracy.png", dpi=300)
plt.close()

plt.figure(figsize=(10, 6))
plt.plot(train_loss_list, label="Training Loss", color='red')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("nn_train_loss.png", dpi=300)
plt.close()
print("Training and validation plots saved.")

# ⚠️ Optional: Plot Decision Boundary (only if features = 2)
if X_train.shape[1] == 2:
    def plot_decision_boundary(model, X, y, filename='nn_decision_boundary.png'):
        x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
        y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
        xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                             np.linspace(y_min, y_max, 300))
        grid = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32)
        with torch.no_grad():
            Z = model(grid)
            _, preds = torch.max(Z, 1)
        Z = preds.reshape(xx.shape).numpy()

        plt.figure(figsize=(10, 8))
        plt.contourf(xx, yy, Z, alpha=0.6, cmap=plt.cm.RdYlBu)
        scatter = plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu, edgecolor='k')
        plt.colorbar(scatter)
        plt.title("Neural Network Decision Boundary")
        plt.savefig(filename, dpi=300)
        plt.close()
        print(f"Decision boundary saved as {filename}")

    plot_decision_boundary(model, X_val_scaled.numpy(), y_val_tensor.numpy())
# Out:
# Epoch [1/200], Loss: 0.4958, Validation Accuracy: 0.9252
# Epoch [2/200], Loss: 0.4035, Validation Accuracy: 0.8811
# Epoch [3/200], Loss: 0.3549, Validation Accuracy: 0.8897
# Epoch [4/200], Loss: 0.3128, Validation Accuracy: 0.8946
# Epoch [5/200], Loss: 0.3146, Validation Accuracy: 0.9044
# Epoch [6/200], Loss: 0.2911, Validation Accuracy: 0.9130
# Epoch [7/200], Loss: 0.2734, Validation Accuracy: 0.8946
# Epoch [8/200], Loss: 0.2618, Validation Accuracy: 0.9142
# Epoch [9/200], Loss: 0.2517, Validation Accuracy: 0.9118
# Epoch [10/200], Loss: 0.2609, Validation Accuracy: 0.9093
# Epoch [11/200], Loss: 0.2778, Validation Accuracy: 0.9191
# Epoch [12/200], Loss: 0.2399, Validation Accuracy: 0.9179
# Epoch [13/200], Loss: 0.2227, Validation Accuracy: 0.9105
# Epoch [14/200], Loss: 0.2961, Validation Accuracy: 0.8897
# Epoch [15/200], Loss: 0.2402, Validation Accuracy: 0.9203
# Epoch [16/200], Loss: 0.2682, Validation Accuracy: 0.8860
# Epoch [17/200], Loss: 0.2471, Validation Accuracy: 0.8811
# Epoch [18/200], Loss: 0.2645, Validation Accuracy: 0.9326
# Epoch [19/200], Loss: 0.2395, Validation Accuracy: 0.9056
# Epoch [20/200], Loss: 0.2838, Validation Accuracy: 0.9093
# Epoch [21/200], Loss: 0.2680, Validation Accuracy: 0.9069
# Epoch [22/200], Loss: 0.2344, Validation Accuracy: 0.9142
# Epoch [23/200], Loss: 0.2255, Validation Accuracy: 0.9252
# Epoch [24/200], Loss: 0.2022, Validation Accuracy: 0.9142
# Epoch [25/200], Loss: 0.2577, Validation Accuracy: 0.8983
# Epoch [26/200], Loss: 0.1989, Validation Accuracy: 0.9081
# Epoch [27/200], Loss: 0.2430, Validation Accuracy: 0.9265
# Epoch [28/200], Loss: 0.2324, Validation Accuracy: 0.9265
# Epoch [29/200], Loss: 0.2262, Validation Accuracy: 0.9252
# Epoch [30/200], Loss: 0.2041, Validation Accuracy: 0.9142
# Epoch [31/200], Loss: 0.2216, Validation Accuracy: 0.9154
# Epoch [32/200], Loss: 0.1803, Validation Accuracy: 0.9154
# Epoch [33/200], Loss: 0.1879, Validation Accuracy: 0.9277
# Epoch [34/200], Loss: 0.2288, Validation Accuracy: 0.9105
# Epoch [35/200], Loss: 0.1955, Validation Accuracy: 0.9044
# Epoch [36/200], Loss: 0.2013, Validation Accuracy: 0.9167
# Epoch [37/200], Loss: 0.2477, Validation Accuracy: 0.9277
# Epoch [38/200], Loss: 0.1952, Validation Accuracy: 0.9338
# Epoch [39/200], Loss: 0.2059, Validation Accuracy: 0.9314
# Epoch [40/200], Loss: 0.1961, Validation Accuracy: 0.9130
# Epoch [41/200], Loss: 0.2016, Validation Accuracy: 0.9326
# Epoch [42/200], Loss: 0.1877, Validation Accuracy: 0.9179
# Epoch [43/200], Loss: 0.1683, Validation Accuracy: 0.9240
# Epoch [44/200], Loss: 0.1882, Validation Accuracy: 0.9350
# Epoch [45/200], Loss: 0.1959, Validation Accuracy: 0.9093
# Epoch [46/200], Loss: 0.1985, Validation Accuracy: 0.8983
# Epoch [47/200], Loss: 0.1789, Validation Accuracy: 0.9154
# Epoch [48/200], Loss: 0.1852, Validation Accuracy: 0.9338
# Epoch [49/200], Loss: 0.1922, Validation Accuracy: 0.9314
# Epoch [50/200], Loss: 0.1802, Validation Accuracy: 0.9375
# Epoch [51/200], Loss: 0.1946, Validation Accuracy: 0.9265
# Epoch [52/200], Loss: 0.1723, Validation Accuracy: 0.9179
# Epoch [53/200], Loss: 0.2042, Validation Accuracy: 0.9363
# Epoch [54/200], Loss: 0.1866, Validation Accuracy: 0.9314
# Epoch [55/200], Loss: 0.2015, Validation Accuracy: 0.9252
# Epoch [56/200], Loss: 0.1707, Validation Accuracy: 0.9350
# Epoch [57/200], Loss: 0.1831, Validation Accuracy: 0.9277
# Epoch [58/200], Loss: 0.1779, Validation Accuracy: 0.9314
# Epoch [59/200], Loss: 0.1924, Validation Accuracy: 0.9216
# Epoch [60/200], Loss: 0.1816, Validation Accuracy: 0.9277
# Epoch [61/200], Loss: 0.1757, Validation Accuracy: 0.9314
# Epoch [62/200], Loss: 0.1940, Validation Accuracy: 0.9203
# Epoch [63/200], Loss: 0.1685, Validation Accuracy: 0.9289
# Epoch [64/200], Loss: 0.1628, Validation Accuracy: 0.9387
# Epoch [65/200], Loss: 0.1762, Validation Accuracy: 0.9191
# Epoch [66/200], Loss: 0.1743, Validation Accuracy: 0.9363
# Epoch [67/200], Loss: 0.1766, Validation Accuracy: 0.9338
# Epoch [68/200], Loss: 0.1559, Validation Accuracy: 0.9154
# Epoch [69/200], Loss: 0.1755, Validation Accuracy: 0.9400
# Epoch [70/200], Loss: 0.1687, Validation Accuracy: 0.9289
# Epoch [71/200], Loss: 0.1716, Validation Accuracy: 0.9338
# Epoch [72/200], Loss: 0.1768, Validation Accuracy: 0.9338
# Epoch [73/200], Loss: 0.1787, Validation Accuracy: 0.9179
# Epoch [74/200], Loss: 0.1628, Validation Accuracy: 0.9154
# Epoch [75/200], Loss: 0.1800, Validation Accuracy: 0.9338
# Epoch [76/200], Loss: 0.1669, Validation Accuracy: 0.9461
# Epoch [77/200], Loss: 0.1652, Validation Accuracy: 0.9301
# Epoch [78/200], Loss: 0.1808, Validation Accuracy: 0.9375
# Epoch [79/200], Loss: 0.1781, Validation Accuracy: 0.9301
# Epoch [80/200], Loss: 0.1732, Validation Accuracy: 0.9314
# Epoch [81/200], Loss: 0.1659, Validation Accuracy: 0.9265
# Epoch [82/200], Loss: 0.1708, Validation Accuracy: 0.9326
# Epoch [83/200], Loss: 0.1793, Validation Accuracy: 0.9252
# Epoch [84/200], Loss: 0.1699, Validation Accuracy: 0.9350
# Epoch [85/200], Loss: 0.1788, Validation Accuracy: 0.9240
# Epoch [86/200], Loss: 0.1688, Validation Accuracy: 0.9363
# Epoch [87/200], Loss: 0.1570, Validation Accuracy: 0.9363
# Epoch [88/200], Loss: 0.1600, Validation Accuracy: 0.9338
# Epoch [89/200], Loss: 0.1689, Validation Accuracy: 0.9301
# Epoch [90/200], Loss: 0.1632, Validation Accuracy: 0.9350
# Epoch [91/200], Loss: 0.1724, Validation Accuracy: 0.9130
# Epoch [92/200], Loss: 0.1702, Validation Accuracy: 0.9326
# Epoch [93/200], Loss: 0.1685, Validation Accuracy: 0.9179
# Epoch [94/200], Loss: 0.1634, Validation Accuracy: 0.9400
# Epoch [95/200], Loss: 0.1595, Validation Accuracy: 0.9387
# Epoch [96/200], Loss: 0.1631, Validation Accuracy: 0.9363
# Epoch [97/200], Loss: 0.1700, Validation Accuracy: 0.9387
# Epoch [98/200], Loss: 0.1711, Validation Accuracy: 0.9375
# Epoch [99/200], Loss: 0.1650, Validation Accuracy: 0.9338
# Epoch [100/200], Loss: 0.1479, Validation Accuracy: 0.9375
# Epoch [101/200], Loss: 0.1636, Validation Accuracy: 0.9350
# Epoch [102/200], Loss: 0.1535, Validation Accuracy: 0.9240
# Epoch [103/200], Loss: 0.1600, Validation Accuracy: 0.9338
# Epoch [104/200], Loss: 0.1564, Validation Accuracy: 0.9387
# Epoch [105/200], Loss: 0.1696, Validation Accuracy: 0.9301
# Epoch [106/200], Loss: 0.1773, Validation Accuracy: 0.9216
# Epoch [107/200], Loss: 0.1560, Validation Accuracy: 0.9350
# Epoch [108/200], Loss: 0.1576, Validation Accuracy: 0.9301
# Epoch [109/200], Loss: 0.1605, Validation Accuracy: 0.9314
# Epoch [110/200], Loss: 0.1610, Validation Accuracy: 0.9314
# Epoch [111/200], Loss: 0.1586, Validation Accuracy: 0.9375
# Epoch [112/200], Loss: 0.1520, Validation Accuracy: 0.9387
# Epoch [113/200], Loss: 0.1621, Validation Accuracy: 0.9412
# Epoch [114/200], Loss: 0.1648, Validation Accuracy: 0.9301
# Epoch [115/200], Loss: 0.1542, Validation Accuracy: 0.9314
# Epoch [116/200], Loss: 0.1739, Validation Accuracy: 0.9387
# Epoch [117/200], Loss: 0.1502, Validation Accuracy: 0.9301
# Epoch [118/200], Loss: 0.1593, Validation Accuracy: 0.9350
# Epoch [119/200], Loss: 0.1565, Validation Accuracy: 0.9216
# Epoch [120/200], Loss: 0.1590, Validation Accuracy: 0.9191
# Epoch [121/200], Loss: 0.1592, Validation Accuracy: 0.9314
# Epoch [122/200], Loss: 0.1523, Validation Accuracy: 0.9301
# Epoch [123/200], Loss: 0.1644, Validation Accuracy: 0.9338
# Epoch [124/200], Loss: 0.1588, Validation Accuracy: 0.9179
# Epoch [125/200], Loss: 0.1635, Validation Accuracy: 0.9363
# Epoch [126/200], Loss: 0.1620, Validation Accuracy: 0.9363
# Epoch [127/200], Loss: 0.1483, Validation Accuracy: 0.9289
# Epoch [128/200], Loss: 0.1657, Validation Accuracy: 0.9289
# Epoch [129/200], Loss: 0.1507, Validation Accuracy: 0.9326
# Epoch [130/200], Loss: 0.1574, Validation Accuracy: 0.9400
# Epoch [131/200], Loss: 0.1547, Validation Accuracy: 0.9375
# Epoch [132/200], Loss: 0.1595, Validation Accuracy: 0.9412
# Epoch [133/200], Loss: 0.1624, Validation Accuracy: 0.9387
# Epoch [134/200], Loss: 0.1670, Validation Accuracy: 0.9412
# Epoch [135/200], Loss: 0.1503, Validation Accuracy: 0.9400
# Epoch [136/200], Loss: 0.1582, Validation Accuracy: 0.9375
# Epoch [137/200], Loss: 0.1527, Validation Accuracy: 0.9387
# Epoch [138/200], Loss: 0.1657, Validation Accuracy: 0.9400
# Epoch [139/200], Loss: 0.1766, Validation Accuracy: 0.9387
# Epoch [140/200], Loss: 0.1538, Validation Accuracy: 0.9326
# Epoch [141/200], Loss: 0.1606, Validation Accuracy: 0.9167
# Epoch [142/200], Loss: 0.1519, Validation Accuracy: 0.9363
# Epoch [143/200], Loss: 0.1542, Validation Accuracy: 0.9326
# Epoch [144/200], Loss: 0.1719, Validation Accuracy: 0.9203
# Epoch [145/200], Loss: 0.1585, Validation Accuracy: 0.9375
# Epoch [146/200], Loss: 0.1550, Validation Accuracy: 0.9375
# Epoch [147/200], Loss: 0.1527, Validation Accuracy: 0.9314
# Epoch [148/200], Loss: 0.1517, Validation Accuracy: 0.9387
# Epoch [149/200], Loss: 0.1675, Validation Accuracy: 0.9387
# Epoch [150/200], Loss: 0.1576, Validation Accuracy: 0.9338
# Epoch [151/200], Loss: 0.1697, Validation Accuracy: 0.9412
# Epoch [152/200], Loss: 0.1585, Validation Accuracy: 0.9375
# Epoch [153/200], Loss: 0.1514, Validation Accuracy: 0.9375
# Epoch [154/200], Loss: 0.1747, Validation Accuracy: 0.9326
# Epoch [155/200], Loss: 0.1694, Validation Accuracy: 0.9387
# Epoch [156/200], Loss: 0.1656, Validation Accuracy: 0.9375
# Epoch [157/200], Loss: 0.1643, Validation Accuracy: 0.9301
# Epoch [158/200], Loss: 0.1587, Validation Accuracy: 0.9363
# Epoch [159/200], Loss: 0.1612, Validation Accuracy: 0.9387
# Epoch [160/200], Loss: 0.1661, Validation Accuracy: 0.9338
# Epoch [161/200], Loss: 0.1562, Validation Accuracy: 0.9314
# Epoch [162/200], Loss: 0.1676, Validation Accuracy: 0.9338
# Epoch [163/200], Loss: 0.1573, Validation Accuracy: 0.9301
# Epoch [164/200], Loss: 0.1558, Validation Accuracy: 0.9350
# Epoch [165/200], Loss: 0.1542, Validation Accuracy: 0.9375
# Epoch [166/200], Loss: 0.1473, Validation Accuracy: 0.9265
# Epoch [167/200], Loss: 0.1489, Validation Accuracy: 0.9400
# Epoch [168/200], Loss: 0.1543, Validation Accuracy: 0.9363
# Epoch [169/200], Loss: 0.1533, Validation Accuracy: 0.9326
# Epoch [170/200], Loss: 0.1571, Validation Accuracy: 0.9289
# Epoch [171/200], Loss: 0.1540, Validation Accuracy: 0.9338
# Epoch [172/200], Loss: 0.1664, Validation Accuracy: 0.9363
# Epoch [173/200], Loss: 0.1658, Validation Accuracy: 0.9387
# Epoch [174/200], Loss: 0.1587, Validation Accuracy: 0.9375
# Epoch [175/200], Loss: 0.1508, Validation Accuracy: 0.9228
# Epoch [176/200], Loss: 0.1745, Validation Accuracy: 0.9301
# Epoch [177/200], Loss: 0.1492, Validation Accuracy: 0.9350
# Epoch [178/200], Loss: 0.1534, Validation Accuracy: 0.9375
# Epoch [179/200], Loss: 0.1545, Validation Accuracy: 0.9326
# Epoch [180/200], Loss: 0.1491, Validation Accuracy: 0.9387
# Epoch [181/200], Loss: 0.1602, Validation Accuracy: 0.9363
# Epoch [182/200], Loss: 0.1532, Validation Accuracy: 0.9289
# Epoch [183/200], Loss: 0.1515, Validation Accuracy: 0.9350
# Epoch [184/200], Loss: 0.1676, Validation Accuracy: 0.9375
# Epoch [185/200], Loss: 0.1563, Validation Accuracy: 0.9301
# Epoch [186/200], Loss: 0.1604, Validation Accuracy: 0.9338
# Epoch [187/200], Loss: 0.1627, Validation Accuracy: 0.9363
# Epoch [188/200], Loss: 0.1584, Validation Accuracy: 0.9326
# Epoch [189/200], Loss: 0.1590, Validation Accuracy: 0.9350
# Epoch [190/200], Loss: 0.1482, Validation Accuracy: 0.9363
# Epoch [191/200], Loss: 0.1488, Validation Accuracy: 0.9338
# Epoch [192/200], Loss: 0.1484, Validation Accuracy: 0.9375
# Epoch [193/200], Loss: 0.1536, Validation Accuracy: 0.9314
# Epoch [194/200], Loss: 0.1553, Validation Accuracy: 0.9301
# Epoch [195/200], Loss: 0.1552, Validation Accuracy: 0.9228
# Epoch [196/200], Loss: 0.1507, Validation Accuracy: 0.9375
# Epoch [197/200], Loss: 0.1539, Validation Accuracy: 0.9277
# Epoch [198/200], Loss: 0.1500, Validation Accuracy: 0.9326
# Epoch [199/200], Loss: 0.1488, Validation Accuracy: 0.9350
# Epoch [200/200], Loss: 0.1490, Validation Accuracy: 0.9301
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        95
#            1     1.0000    1.0000    1.0000        83
#            2     0.7532    0.6170    0.6784        94
#            3     1.0000    0.9885    0.9942        87
#            4     1.0000    1.0000    1.0000        95
#            5     1.0000    1.0000    1.0000        91
#            6     0.9882    1.0000    0.9941        84
#            7     0.6726    0.7917    0.7273        96
#            8     1.0000    1.0000    1.0000        91
#
#     accuracy                         0.9301       816
#    macro avg     0.9349    0.9330    0.9327       816
# weighted avg     0.9318    0.9301    0.9296       816
#
# Confusion matrix saved as nn_confusion_matrix.png
#
# Final Metrics:
# ✅ Accuracy:  0.9301
# ✅ Precision: 0.9318
# ✅ Recall:    0.9301
# ✅ F1 Score:  0.9296
# Training and validation plots saved.

# %%
from sklearn.naive_bayes import GaussianNB

# ✅ Initialize and Train
nb_model = GaussianNB()
nb_model.fit(X_train, y_train - 1)

# ✅ Predict
y_pred_nb = nb_model.predict(X_val)

# ✅ Evaluation
print("🤖 Naive Bayes (scikit-learn) Results:")
print(classification_report(y_val - 1, y_pred_nb, digits=4))

# ✅ Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_val - 1, y_pred_nb), annot=True, fmt='d', cmap='Oranges')
plt.title("Naive Bayes - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig("naive_bayes_confusion_matrix.png", dpi=300)
plt.close()
# Out:
# 🤖 Naive Bayes (scikit-learn) Results:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        95
#            1     1.0000    1.0000    1.0000        83
#            2     0.7424    0.5213    0.6125        94
#            3     1.0000    1.0000    1.0000        87
#            4     1.0000    1.0000    1.0000        95
#            5     1.0000    1.0000    1.0000        91
#            6     1.0000    1.0000    1.0000        84
#            7     0.6371    0.8229    0.7182        96
#            8     1.0000    1.0000    1.0000        91
#
#     accuracy                         0.9240       816
#    macro avg     0.9311    0.9271    0.9256       816
# weighted avg     0.9276    0.9240    0.9222       816
